# %%
import pandas as pd

# %%
df_rating = pd.read_csv("analyst_ratings_processed.csv")
df_analyst = pd.read_csv("raw_analyst_ratings.csv")
df_headline = pd.read_csv("raw_partner_headlines.csv")

# %% [markdown]
# https://github.com/msnews/msnews.github.io/blob/master/assets/doc/introduction.md

# %%
# https://www.kaggle.com/datasets/aaron7sun/stocknews/data?select=upload_DJIA_table.csv
df = pd.read_csv("Combined_News_DJIA.csv")
df.head()
# Out:
#          Date  Label                                               Top1  \
# 0  2008-08-08      0  b"Georgia 'downs two Russian warplanes' as cou...
# 1  2008-08-11      1  b'Why wont America and Nato help us? If they w...
# 2  2008-08-12      0  b'Remember that adorable 9-year-old who sang a...
# 3  2008-08-13      0  b' U.S. refuses Israel weapons to attack Iran:...
# 4  2008-08-14      1  b'All the experts admit that we should legalis...
#
#                                                 Top2  \
# 0            b'BREAKING: Musharraf to be impeached.'
# 1        b'Bush puts foot down on Georgian conflict'
# 2                 b"Russia 'ends Georgia operation'"
# 3  b"When the president ordered to attack Tskhinv...
# 4  b'War in South Osetia - 89 pictures made by a ...
#
#                                                 Top3  \
# 0  b'Russia Today: Columns of troops roll into So...
# 1  b"Jewish Georgian minister: Thanks to Israeli ...
# ...

# %%
df_table = pd.read_csv("upload_DJIA_table.csv")
df_reddit = pd.read_csv("RedditNews.csv")

# %%
df_table.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
# 1  2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2  2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 3  2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 4  2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
#
#       Volume     Adj Close
# 0   82160000  17949.369141
# 1  133030000  17929.990234
# 2  106380000  17694.679688
# 3  112190000  17409.720703
# 4  138740000  17140.240234

# %%
df_table.tail()
# Out:
#             Date          Open          High           Low         Close  \
# 1984  2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
# 1985  2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 1986  2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 1987  2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 1988  2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312
#
#          Volume     Adj Close
# 1984  159790000  11615.929688
# 1985  182550000  11532.959961
# 1986  173590000  11642.469727
# 1987  183190000  11782.349609
# 1988  212830000  11734.320312

# %%
df_reddit.head()
# Out:
#          Date                                               News
# 0  2016-07-01  A 117-year-old woman in Mexico City finally re...
# 1  2016-07-01   IMF chief backs Athens as permanent Olympic host
# 2  2016-07-01  The president of France says if Brexit won, so...
# 3  2016-07-01  British Man Who Must Give Police 24 Hours' Not...
# 4  2016-07-01  100+ Nobel laureates urge Greenpeace to stop o...

# %%
# !pip install --upgrade yfinance
# Out:
# ...
#    ---------------------------------------- 0.0/101.0 kB ? eta -:--:--
#    ---------------------------------------- 101.0/101.0 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: yfinance
#     Found existing installation: yfinance 0.2.36
#     Uninstalling yfinance-0.2.36:
#       Successfully uninstalled yfinance-0.2.36
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip install --upgrade numpy
#!pip install --upgrade pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !pip uninstall pandas yfinance
# !pip install pandas yfinance
# Out:
# ^C

# %%
# !pip install --upgrade pandas
# Out:
# ...
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.6 MB 16.8 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.5/11.6 MB 19.4 MB/s eta 0:00:01
#    -------- ------------------------------- 2.4/11.6 MB 18.8 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.3/11.6 MB 19.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.1/11.6 MB 18.8 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.1/11.6 MB 19.2 MB/s eta 0:00:01
#    --------------------- ------------------ 6.2/11.6 MB 19.8 MB/s eta 0:00:01
#    ------------------------ --------------- 7.3/11.6 MB 20.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 8.4/11.6 MB 20.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.9/11.6 MB 20.5 MB/s eta 0:00:01
#    --------------------------------- ------ 9.7/11.6 MB 19.5 MB/s eta 0:00:01
# ...

# %%
# import the finance data from yf
import yfinance as yf

start = "2008-08-08"
end = "2016-07-02"

# S&P 500 
dj= yf.download("^DJI", start=start, end=end)

# gold price
gold = yf.download("GC=F", start="2008-08-08", end="2016-07-02", interval="1d")

# 10y bond
us10y = yf.download("^TNX", start="2008-08-08", end="2016-07-02", interval="1d")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 # import the finance data from yf
# ----> 2 import yfinance as yf
#       4 start = "2008-08-08"
#       5 end = "2016-07-02"
#
# File c:\Users\dicod\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\__init__.py:23
#       1 #!/usr/bin/env python
#       2 # -*- coding: utf-8 -*-
#       3 #
#    (...)
#      19 # limitations under the License.
#      20 #
#      22 from . import version
# ---> 23 from .ticker import Ticker
#      24 from .tickers import Tickers
#      25 from .multi import download
#
# File c:\Users\dicod\AppData\Local\Programs\Python\Python311\Lib\site-packages\yfinance\ticker.py:25
#      22 from __future__ import print_function
#      24 from collections import namedtuple as _namedtuple
# ---> 25 from .scrapers.funds import FundsData
#      27 import pandas as _pd
# ...

# %%
# Rename the columns
dj.rename(columns={'Close': 'dj_close', 'Volume': 'dj_volume'}, inplace=True)
gold.rename(columns={'Close': 'gold_close'}, inplace=True)
us10y.rename(columns={'Close': 'us10y_close'}, inplace=True)

# %%
merged_data = pd.concat([dj, gold, us10y], axis=1)

# %%
merged_data
# Out:
#                     Open          High           Low      dj_close  \
# Date
# 2008-08-08  11432.089844  11759.959961  11388.040039  11734.320312
# 2008-08-11  11729.669922  11867.110352  11675.530273  11782.349609
# 2008-08-12  11781.700195  11782.349609  11601.519531  11642.469727
# 2008-08-13  11632.809570  11633.780273  11453.339844  11532.959961
# 2008-08-14  11532.070312  11718.280273  11450.889648  11615.929688
# ...                  ...           ...           ...           ...
# 2016-06-27  17355.210938  17355.210938  17063.080078  17140.240234
# 2016-06-28  17190.509766  17409.720703  17190.509766  17409.720703
# 2016-06-29  17456.019531  17704.509766  17456.019531  17694.679688
# 2016-06-30  17712.759766  17930.609375  17711.800781  17929.990234
# 2016-07-01  17924.240234  18002.380859  17916.910156  17949.369141
#
#                Adj Close  dj_volume         Open         High          Low  \
# Date
# ...

# %%
merged_data.head()
# Out:
#                              Open          High           Low         Close  \
# 2008-08-08 00:00:00  11432.089844  11759.959961  11388.040039  11734.320312
# 2008-08-11 00:00:00  11729.669922  11867.110352  11675.530273  11782.349609
# 2008-08-12 00:00:00  11781.700195  11782.349609  11601.519531  11642.469727
# 2008-08-13 00:00:00  11632.809570  11633.780273  11453.339844  11532.959961
# 2008-08-14 00:00:00  11532.070312  11718.280273  11450.889648  11615.929688
#
#                         Adj Close       Volume        Open        High  \
# 2008-08-08 00:00:00  11734.320312  212830000.0  868.799988  869.500000
# 2008-08-11 00:00:00  11782.349609  183190000.0  858.299988  863.400024
# 2008-08-12 00:00:00  11642.469727  173590000.0  826.400024  826.400024
# 2008-08-13 00:00:00  11532.959961  182550000.0  810.900024  829.099976
# 2008-08-14 00:00:00  11615.929688  159790000.0  831.400024  831.900024
#
#                             Low       Close  ...  Top18  Top19  Top20  Top21  \
# ...

# %%
merged_data = merged_data[["dj_close", "dj_volume", "gold_close","us10y_close"]]
df = merged_data.reset_index()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1989 entries, 0 to 1988
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         1989 non-null   datetime64[ns]
#  1   dj_close     1989 non-null   float64
#  2   dj_volume    1989 non-null   int64
#  3   gold_close   1989 non-null   float64
#  4   us10y_close  1988 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 77.8 KB

# %% [markdown]
# # 여기서부터... df and new data concat

# %%
df

# %%
# !pip install pandas_datareader
# Out:
# ...
#    ---------------------------------------- 0.0/109.5 kB ? eta -:--:--
#    ------------------------------------- -- 102.4/109.5 kB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 109.5/109.5 kB 2.1 MB/s eta 0:00:00
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas_datareader.data as web
from datetime import datetime

# data period setting
start = datetime(2008, 1, 1)
end = datetime(2016, 7, 1)

# data import
gdp_growth = web.DataReader("GDP", "fred", start, end)         # GDP quaterly
unemployment = web.DataReader("UNRATE", "fred", start, end)    # monthly
cpi = web.DataReader("CPIAUCSL", "fred", start, end)           # monthly
ppi = web.DataReader("PPIACO", "fred", start, end)             # monthly
interest_rate = web.DataReader("DFF", "fred", start, end)      # daily
exchange_rate = web.DataReader("DEXUSEU", "fred", start, end)  # daily(EU/USD)


print(gdp_growth.head())
print(unemployment.head())
print(cpi.head())
# Out:
#                   GDP
# DATE
# 2008-10-01  14608.209
# 2009-01-01  14430.902
# 2009-04-01  14381.236
# 2009-07-01  14448.882
# 2009-10-01  14651.249
#             UNRATE
# DATE
# 2008-09-01     6.1
# 2008-10-01     6.5
# 2008-11-01     6.8
# 2008-12-01     7.3
# 2009-01-01     7.8
#             CPIAUCSL
# DATE
# 2008-09-01   218.877
# 2008-10-01   216.995
# 2008-11-01   213.153
# 2008-12-01   211.398
# 2009-01-01   211.933

# %%
exchange_rate = yf.download("EURUSD=X", start="2008-01-01", end="2016-12-31", interval="1d")
print(exchange_rate.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                 Open      High       Low     Close  Adj Close  Volume
# Date
# 2008-01-01  1.460110  1.462994  1.458194  1.462010   1.462010       0
# 2008-01-02  1.462309  1.474296  1.460110  1.471692   1.471692       0
# 2008-01-03  1.471692  1.477891  1.469400  1.474491   1.474491       0
# 2008-01-04  1.474709  1.481811  1.469896  1.475492   1.475492       0
# 2008-01-07  1.475209  1.475209  1.466706  1.468299   1.468299       0

# %%
gdp_growth_daily = gdp_growth.resample('D').ffill()  # Resample to daily and forward-fill
unemployment_daily = unemployment.resample('D').ffill()
cpi_daily = cpi.resample('D').ffill()
ppi_daily = ppi.resample('D').ffill()

# %%
merged_data = pd.concat([gdp_growth_daily, unemployment_daily, cpi_daily, ppi_daily, interest_rate, exchange_rate], axis=1)

# %%
merged_data.columns = ['GDP', 'Unemployment', 'CPI', 'PPI', 'Interest Rate', 'Exchange Rate']

# %%
# first I merge the daily data.
# [dow_jones_index, gdp, umemployeement, cpi, ppi, interests, ex_rates, gold, bond_10y, news1, ... ,news8] on daily

# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime

# %%
import pandas as pd
import pandas_datareader.data as web
from datetime import datetime

# Set the date range
start = datetime(2008, 1, 8)
end = datetime(2016, 7, 1)

# Retrieve daily data
interest_rate = web.DataReader("DFF", "fred", start, end)      # daily
exchange_rate = web.DataReader("DEXUSEU", "fred", start, end)  # daily (EUR/USD)

# Retrieve quarterly and monthly data
gdp_growth = web.DataReader("GDP", "fred", start, end)         # GDP quarterly
unemployment = web.DataReader("UNRATE", "fred", start, end)    # monthly
cpi = web.DataReader("CPIAUCSL", "fred", start, end)           # monthly
ppi = web.DataReader("PPIACO", "fred", start, end)             # monthly

# Forward-fill the monthly and quarterly data to create daily data
gdp_growth_daily = gdp_growth.resample('D').ffill()  # Resample to daily and forward-fill
unemployment_daily = unemployment.resample('D').ffill()
cpi_daily = cpi.resample('D').ffill()
ppi_daily = ppi.resample('D').ffill()

# Merge all data into a single DataFrame
merged_data = pd.concat([gdp_growth_daily, unemployment_daily, cpi_daily, ppi_daily, interest_rate, exchange_rate], axis=1)

# Rename columns for clarity
merged_data.columns = ['GDP', 'Unemployment', 'CPI', 'PPI', 'Interest Rate', 'Exchange Rate']

# Display the merged data
print(merged_data.head())
# Out:
#             GDP  Unemployment  CPI  PPI  Interest Rate  Exchange Rate
# DATE
# 2008-01-08  NaN           NaN  NaN  NaN           4.27         1.4717
# 2008-01-09  NaN           NaN  NaN  NaN           4.26         1.4663
# 2008-01-10  NaN           NaN  NaN  NaN           4.26         1.4740
# 2008-01-11  NaN           NaN  NaN  NaN           4.23         1.4787
# 2008-01-12  NaN           NaN  NaN  NaN           4.23            NaN
